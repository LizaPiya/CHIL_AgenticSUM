# %%
import pandas as pd

# Load
df = pd.read_csv("/lustre/hl/users/4283/outputs/agenticsum/agenticsum_results_MIMIC.csv")

# Display
df[["note_id", "draft_summary", "fixed_summary", "target"]]
# Out:
#            note_id                                      draft_summary  \
# 0   16002318-DS-17  Patient was admitted for post-operative care f...
# 1    15638884-DS-4  Mr. ___ is a middle-aged man with a history of...
# 2   12435705-DS-14  Lumbar puncture confirmed bacterial meningitis...
# 3    12413577-DS-4  The patient was admitted to the hospital for a...
# 4   17967161-DS-29  Mr. ___ was admitted after months of worsening...
# ..             ...                                                ...
# 95  19859533-DS-16  The patient was admitted to the hospital for a...
# 96  17018866-DS-21  Ms. ___ is a middle-aged woman with catastroph...
# 97  12627553-DS-13  The patient was admitted to the transplant sur...
# 98  15710368-DS-12  Patient was admitted to the hospital for a fra...
# 99  17989869-DS-18  The patient was urgently transferred after a c...
#
#                                         fixed_summary  \
# 0   The patient was alert and oriented, with no si...
# 1   Mr. ___ is a man with significant cardiovascul...
# 2   Mr. ___ is a man with Philadelphia chromosome–...
# 3   Ms. ___ was admitted to the gynecology service...
# 4   Mr. ___ underwent an angiogram on ___ that dem...
# ..                                                ...
# 95  The patient experienced mild tenderness and br...
# 96  Ms. ___ is a woman with severe peripheral vasc...
# 97  Patient was admitted with severe abdominal pai...
# 98  The patient was treated with alendronate, warf...
# 99  The patient was admitted directly to the ortho...
#
#                                                target
# 0   This is a ___ yo F admitted to the hospital af...
# 1   Mr. ___ is a ___ yo man with CAD with prior MI...
# 2   Mr. ___ is a ___ w/ Ph+ve ALL on dasatanib and...
# 3   On ___, Ms. ___ was admitted to the gynecology...
# 4   Mr. ___ underwent an angiogram on ___ which sh...
# ..                                                ...
# 95  Mrs. ___ was taken to the angiography suite on...
# 96  SUMMARY STATEMENT ================= Ms. ___ is...
# 97  Patient was admitted to the transplant surgery...
# 98  Ms. ___ is an ___ year old female who had a me...
# 99  The patient presented from ___ to ___ ___ wher...
#
# [100 rows x 4 columns]

# %%
import sys
from unittest.mock import MagicMock
from importlib.machinery import ModuleSpec

def mock_module(name):
    mod = MagicMock()
    mod.__spec__ = ModuleSpec(name, None)
    mod.__name__ = name
    sys.modules[name] = mod

mock_module("matplotlib")
mock_module("matplotlib.pyplot")
mock_module("mpl_toolkits")
mock_module("mpl_toolkits.axes_grid1")

# %%
import os
print(os.getcwd())
print(os.listdir("."))
# Out:
# /lustre/hl/users/4283/agentic_paper/CHIL/Agents_CHIL
# ['run_agenticsum.py', 'HallucinationDetectorAgent_v1.py', '__pycache__', '.ipynb_checkpoints', 'ClinicalSupervisorAgent.py', 'run_agenticsum_v1.py', 'Soap_Evaluation.ipynb', 'run_agenticsum_SOAP.sbatch', 'Soap_run_agenticsum.py', 'FixAgent.py', 'focus_agent_v1.py', 'Evaluation.py', 'HallucinationDetectorAgent.py', 'run_agenticsum.sbatch', 'semantic_entailment_judge.py', 'Evaluation.ipynb', 'llm_as_a_judge.ipynb', 'draft_agent.py', 'focus_agent.py', 'RunPipeline.ipynb', 'llama_judge_results.csv', 'llm_as_a_judge.py']

# %%
exec(open("Evaluation.py").read())

df_eval = evaluate_summaries(df)
# Out:
# 📊 Evaluating 100 summaries...
#    Summary column:   fixed_summary
#    Reference column: target
# BLEU + ROUGE-L: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 87.26it/s]
# 🧠 Computing BERTScore...
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ==================================================
# 📊 EVALUATION RESULTS
# ==================================================
# Metric             Mean     Median
# --------------------------------------------------
# ROUGE-L           21.62      14.06
# BLEU-1            18.37      10.66
# BLEU-2            12.61       4.84
# BERTScore         84.50      83.59
# ==================================================
